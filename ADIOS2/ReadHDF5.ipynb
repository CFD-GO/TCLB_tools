# %%
import h5py
import matplotlib.pyplot as plt
import numpy as np

# %%
data = h5py.File('./mask.hdf5')
plt.figure(figsize=(10,10))
print(data['Step3']['GlobalArray'].shape)
plt.imshow(np.array(data['Step3']['GlobalArray']))
# Out:
# (734, 20)

# %%
tmp = list()
for i in range(50):
    tmp.append(data['Step%d'%i]['GlobalArray'][:, 300])

plt.imshow(np.vstack(tmp))
