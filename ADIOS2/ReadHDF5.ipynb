# %%
import h5py
import matplotlib.pyplot as plt

# %%
data = h5py.File('./mask.hdf5')

# %%
data.keys()
# Out:
# <KeysViewHDF5 ['Step0', 'Step1', 'Step2', 'Step3', 'Step4', 'Step5', 'Step6', 'Step7', 'Step8', 'Step9']>

# %%
plt.imshow(data['Step9']['GlobalArray'])
